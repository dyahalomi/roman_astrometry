# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from simulate import *



import matplotlib 
matplotlib.rc('xtick', labelsize=27) 
matplotlib.rc('ytick', labelsize=27)
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
##################
##################
##################
##################
#begin simulate data
##################
##################
##################
##################
##################

T_subtract = 2454000
# orbital parameters from https://www.princeton.edu/~willman/planetary_systems/Sol/
# BJD determined by converting values above using https://ssd.jpl.nasa.gov/tc.cgi#top

m_sun = 333030 #earth masses

P_earth = 300
e_earth = 0.0167
Tper_earth= 100
omega_earth = np.radians(102.9)
Omega_earth = np.radians(0.0)
inclination_earth = np.radians(45.)
m_earth = 1./m_sun #units m_sun



P_jup = 4327.
e_jup = 0.0484
Tper_jup = 500
omega_jup = np.radians(274.3) - 2*np.pi
Omega_jup = np.radians(100.4)
inclination_jup = np.radians(1.31) + inclination_earth
m_jup = 317.83/m_sun #units m_sun





#add gaia observing times
times_observed_astrometry_gaia = []
t_0 = int(Tper_earth)
for ii in range(t_0, t_0+3600):
    if ii % (3600/200) == 0:
        times_observed_astrometry_gaia.append(ii)



#add THE observing times
times_observed_rv = []
t_0 = int(Tper_earth)
add_data = True
for ii in range(t_0, t_0+3600):

    if ii % 180 == 0:
        if add_data:
            add_data = False
        else:
            add_data = True

    if add_data:
        times_observed_rv.append(ii)


orbit_params_earth = [P_earth, e_earth, Tper_earth, omega_earth, Omega_earth, inclination_earth, m_earth]
orbit_params_jup = [P_jup, e_jup, Tper_jup, omega_jup, Omega_jup, inclination_jup, m_jup]

n_planets = 2
orbit_params = [orbit_params_earth, orbit_params_jup]


sigma_rv = 0.3

sigma_ra_gaia = 6e-5
sigma_dec_gaia = 6e-5
parallax = 0.1 #as



times, rv_results, ra_results, dec_results = simulate_data(
    n_planets, 
    sigma_rv, 
    sigma_ra_gaia,
    sigma_dec_gaia,
    parallax,
    orbit_params,
    times_observed_rv = times_observed_rv,
    times_observed_astrometry = times_observed_astrometry_gaia
    )


[[times_rv, times_observed_rv, times_astrometry, times_observed_astrometry],
[rv_orbit, rv_orbit_sum, rv_sim, rv_sim_sum],
[ra_orbit, ra_orbit_sum, ra_sim, ra_sim_sum],
[dec_orbit, dec_orbit_sum, dec_sim, dec_sim_sum]]  = times, rv_results, ra_results, dec_results

ra_gaia_err = np.full(np.shape(ra_sim_sum), sigma_ra_gaia)
dec_gaia_err = np.full(np.shape(dec_sim_sum), sigma_dec_gaia)


#add roman observing times if roman_err not None
if roman_err is not None:
    t_1 =  times_observed_astrometry_gaia[-1]+1800
    times_observed_astrometry_roman = []
    for ii in range(t_1, t_1+(roman_duration*365)):
        if ii % 90 == 0:
            times_observed_astrometry_roman.append(ii)	


    sigma_ra_roman = roman_err
    sigma_dec_roman = roman_err



    times, rv_results, ra_results, dec_results = simulate_data(
        n_planets, 
        sigma_rv, 
        sigma_ra_roman,
        sigma_dec_roman,
        parallax,
        orbit_params,
        times_observed_rv = times_observed_rv,
        times_observed_astrometry = times_observed_astrometry_roman
        )

    times_astrometry = np.append(times_astrometry, times[2], axis=0)

    times_observed_astrometry = np.append(times_observed_astrometry, times[3], axis=0)

    ra_orbit = np.append(ra_orbit, ra_results[0], axis=0)
    ra_orbit_sum = np.append(ra_orbit_sum, ra_results[1], axis=0)
    ra_sim = np.append(ra_sim, ra_results[2], axis=0)
    ra_sim_sum = np.append(ra_sim_sum, ra_results[3], axis=0)

    dec_orbit = np.append(dec_orbit, dec_results[0], axis=0)
    dec_orbit_sum = np.append(dec_orbit_sum, dec_results[1], axis=0)
    dec_sim = np.append(dec_sim, dec_results[2], axis=0)
    dec_sim_sum = np.append(dec_sim_sum, dec_results[3], axis=0)

    ra_roman_err = np.full(np.shape(ra_results[3]), sigma_ra_roman)
    dec_roman_err = np.full(np.shape(dec_results[3]), sigma_dec_roman)



##################
##################
##################
##################
#end simulate data
##################
##################
##################
##################
##################



##################
##################
##################
##################
#begin model data
##################
##################
##################
##################
##################

################
################
#rename variables in more consistent way for modeling
x_rv = np.array(times_observed_rv)
y_rv = rv_sim_sum
y_rv_err = np.full(np.shape(y_rv), sigma_rv)

x_astrometry = np.array(times_observed_astrometry)
ra_data = ra_sim_sum
dec_data = dec_sim_sum


if roman_err is not None:
    ra_err = np.concatenate((ra_gaia_err, ra_roman_err))
    dec_err = np.concatenate((dec_gaia_err, dec_roman_err))

else:
    ra_err = ra_gaia_err
    dec_err = dec_gaia_err
# Out:
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x}(TensorConstant{2})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpwp6pu862/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x}(TensorConstant{2}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_anuelyq8
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x}(TensorConstant{1.0})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpyu7rvlwf/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x}(TensorConstant{1.0}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_txij35eb
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x}(TensorConstant{1.0})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpk4fgncu3/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x}(TensorConstant{1.0}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_ohoj7a3f
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x,0}(TensorConstant{[ 300. 4327.]})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpmrdvpxgh/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x,0}(TensorConstant{[ 300. 4327.]}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_7qkv_glt
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x,0}(TensorConstant{[0.0167 0.0484]})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmp4vasl36b/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x,0}(TensorConstant{[0.0167 0.0484]}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_rr1glxkx
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x,0}(TensorConstant{[100 500]})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmp5klo0az4/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x,0}(TensorConstant{[100 500]}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_jg4w8zbn
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{0,x}(TensorConstant{[ 100.    ...        ]})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmp70c8h8qa/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{0,x}(TensorConstant{[ 100.    ...        ]}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_1z2t05zr
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x,x}(TensorConstant{6.283185307179586})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpn7ayba37/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x,x}(TensorConstant{6.283185307179586}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_c1r9ivxu
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x,0}(TensorConstant{[3.0027324..58466e-04]})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpcrtfml9w/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x,0}(TensorConstant{[3.0027324..58466e-04]}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_smi83rey
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x}(TensorConstant{0.3333333333333333})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmp2yw3c6sb/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x}(TensorConstant{0.3333333333333333}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_vn0pes54
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x}(TensorConstant{74.52695411934832})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpo_k5beps/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x}(TensorConstant{74.52695411934832}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_5pb1wfwb
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: Elemwise{cos,no_inplace}(TensorConstant{[ 1.795943...49574717]})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpwg92s_h7/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(Elemwise{cos,no_inplace}(TensorConstant{[ 1.795943...49574717]}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_7wg7u8h_
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x,x}(TensorConstant{-1.0})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpib218df6/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x,x}(TensorConstant{-1.0}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_yyfdqdko
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: Elemwise{sin,no_inplace}(TensorConstant{[ 1.795943...49574717]})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmppy7pygr9/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(Elemwise{sin,no_inplace}(TensorConstant{[ 1.795943...49574717]}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_m6f97bwd
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x,0}(TensorConstant{[0.7853981...80826198]})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmp64e09hb5/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x,0}(TensorConstant{[0.7853981...80826198]}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_4xg7f5c5
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x,x}(TensorConstant{-8052.083333333333})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpuqyhmw3a/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x,x}(TensorConstant{-8052.083333333333}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_43be71x2
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x,x}(TensorConstant{2})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# ...
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_fmq1ycjf
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x,x}(TensorConstant{1.0})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpceclngfw/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x,x}(TensorConstant{1.0}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_6_frisvt
# ERROR (theano.graph.opt): Optimization failure due to: constant_folding
# ERROR (theano.graph.opt): node: InplaceDimShuffle{x,0}(TensorConstant{[3.0027324..58466e-04]})
# ERROR (theano.graph.opt): TRACEBACK:
# ERROR (theano.graph.opt): Traceback (most recent call last):
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 2017, in process_node
#     replacements = lopt.transform(fgraph, node)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py", line 1209, in transform
#     return self.fn(*args, **kwargs)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py", line 7006, in constant_folding
#     thunk = node.op.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 634, in make_thunk
#     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py", line 600, in make_c_thunk
#     outputs = cl.make_thunk(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1203, in make_thunk
#     cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1138, in __compile__
#     thunk, module = self.cthunk_factory(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1634, in cthunk_factory
#     module = get_module_cache().module_from_key(key=key, lnk=self)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 1191, in module_from_key
#     module = lnk.compile_cmodule(location)
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py", line 1543, in compile_cmodule
#     module = c_compiler.compile_str(
#   File "/Users/Danielyahalomi/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py", line 2546, in compile_str
#     raise Exception(
# Exception: ("Compilation failed (return status=1): In file included from /Users/Danielyahalomi/.theano/compiledir_macOS-12.0.1-x86_64-i386-64bit-i386-3.9.7-64/tmpntmga8xg/mod.cpp:1:. In file included from /Users/Danielyahalomi/anaconda3/envs/py39/include/python3.9/Python.h:25:. /Users/Danielyahalomi/anaconda3/envs/py39/bin/../include/c++/v1/stdio.h:107:15: fatal error: 'stdio.h' file not found. #include_next <stdio.h>.               ^~~~~~~~~. 1 error generated.. ", 'FunctionGraph(InplaceDimShuffle{x,0}(TensorConstant{[3.0027324..58466e-04]}))')
# You can find the C code in this temporary file: /var/folders/l9/xj79z_0x4d306w3wqkty4zq00000gq/T/theano_compilation_error_o09phi09
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-f4b2bdb61ca0> in <module>
#      78
#      79
# ---> 80 times, rv_results, ra_results, dec_results = simulate_data(
#      81     n_planets,
#      82     sigma_rv,
#
# ~/Documents/Columbia/Research/RomanAstrometry/Code/simulate.py in simulate_data(n_planets, sigma_rv, sigma_ra, sigma_dec, plx, orbit_params, times_observed_rv, times_observed_astrometry, t_dur_rv, n_obs_rv, t_dur_astrometry, n_obs_astrometry)
#     149     rv_observed = orbit.get_radial_velocity(times_observed_rv)
#     150
# --> 151     rv_orbit = rv.eval()
#     152
#     153     if n_planets > 1:
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/basic.py in eval(self, inputs_to_values)
#     552         inputs = tuple(sorted(inputs_to_values.keys(), key=id))
#     553         if inputs not in self._fn_cache:
# --> 554             self._fn_cache[inputs] = theano.function(inputs, self)
#     555         args = [inputs_to_values[param] for param in inputs]
#     556
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/compile/function/__init__.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     335         # note: pfunc will also call orig_function -- orig_function is
#     336         #      a choke point that all compilation must pass through
# --> 337         fn = pfunc(
#     338             params=inputs,
#     339             outputs=outputs,
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/compile/function/pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     522         inputs.append(si)
#     523
# --> 524     return orig_function(
#     525         inputs,
#     526         cloned_outputs,
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/compile/function/types.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1968     try:
#    1969         Maker = getattr(mode, "function_maker", FunctionMaker)
# -> 1970         m = Maker(
#    1971             inputs,
#    1972             outputs,
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/compile/function/types.py in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys, name)
#    1613                         )
#    1614                     else:
# -> 1615                         optimizer_profile = optimizer(fgraph)
#    1616
#    1617                     end_optimizer = time.time()
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py in __call__(self, fgraph)
#      90
#      91         """
# ---> 92         return self.optimize(fgraph)
#      93
#      94     def add_requirements(self, fgraph):
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py in optimize(self, fgraph, *args, **kwargs)
#      81         """
#      82         self.add_requirements(fgraph)
# ---> 83         ret = self.apply(fgraph, *args, **kwargs)
#      84         return ret
#      85
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py in apply(self, fgraph)
#     243                     nb_nodes_before = len(fgraph.apply_nodes)
#     244                     t0 = time.time()
# --> 245                     sub_prof = optimizer.optimize(fgraph)
#     246                     l.append(float(time.time() - t0))
#     247                     sub_profs.append(sub_prof)
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py in optimize(self, fgraph, *args, **kwargs)
#      81         """
#      82         self.add_requirements(fgraph)
# ---> 83         ret = self.apply(fgraph, *args, **kwargs)
#      84         return ret
#      85
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py in apply(self, fgraph, start_from)
#    2563                 nb = change_tracker.nb_imported
#    2564                 t_opt = time.time()
# -> 2565                 sub_prof = gopt.apply(fgraph)
#    2566                 time_opts[gopt] += time.time() - t_opt
#    2567                 sub_profs.append(sub_prof)
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py in apply(self, fgraph, start_from)
#    2126                     continue
#    2127                 current_node = node
# -> 2128                 nb += self.process_node(fgraph, node)
#    2129             loop_t = time.time() - t0
#    2130         finally:
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py in process_node(self, fgraph, node, lopt)
#    2015         lopt = lopt or self.local_opt
#    2016         try:
# -> 2017             replacements = lopt.transform(fgraph, node)
#    2018         except Exception as e:
#    2019             if self.failure_callback is not None:
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/opt.py in transform(self, *args, **kwargs)
#    1207
#    1208     def transform(self, *args, **kwargs):
# -> 1209         return self.fn(*args, **kwargs)
#    1210
#    1211     def add_requirements(self, fgraph):
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/tensor/opt.py in constant_folding(fgraph, node)
#    7004     ):
#    7005         impl = "py"
# -> 7006     thunk = node.op.make_thunk(
#    7007         node, storage_map, compute_map, no_recycling=[], impl=impl
#    7008     )
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py in make_thunk(self, node, storage_map, compute_map, no_recycling, impl)
#     632             )
#     633             try:
# --> 634                 return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#     635             except (NotImplementedError, MethodNotDefined):
#     636                 # We requested the c code, so don't catch the error.
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/graph/op.py in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     598                 print(f"Disabling C code for {self} due to unsupported float16")
#     599                 raise NotImplementedError("float16")
# --> 600         outputs = cl.make_thunk(
#     601             input_storage=node_input_storage, output_storage=node_output_storage
#     602         )
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py in make_thunk(self, input_storage, output_storage, storage_map)
#    1201         """
#    1202         init_tasks, tasks = self.get_init_tasks()
# -> 1203         cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#    1204             input_storage, output_storage, storage_map
#    1205         )
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py in __compile__(self, input_storage, output_storage, storage_map)
#    1136         input_storage = tuple(input_storage)
#    1137         output_storage = tuple(output_storage)
# -> 1138         thunk, module = self.cthunk_factory(
#    1139             error_storage,
#    1140             input_storage,
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map)
#    1632             for node in self.node_order:
#    1633                 node.op.prepare_node(node, storage_map, None, "c")
# -> 1634             module = get_module_cache().module_from_key(key=key, lnk=self)
#    1635
#    1636         vars = self.inputs + self.outputs + self.orphans
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py in module_from_key(self, key, lnk)
#    1189             try:
#    1190                 location = dlimport_workdir(self.dirname)
# -> 1191                 module = lnk.compile_cmodule(location)
#    1192                 name = module.__file__
#    1193                 assert name.startswith(location)
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/basic.py in compile_cmodule(self, location)
#    1541             try:
#    1542                 _logger.debug(f"LOCATION {location}")
# -> 1543                 module = c_compiler.compile_str(
#    1544                     module_name=mod.code_hash,
#    1545                     src_code=src_code,
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/link/c/cmodule.py in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2494
#    2495         try:
# -> 2496             p_out = output_subprocess_Popen(cmd)
#    2497             compile_stderr = p_out[1].decode()
#    2498         except Exception:
#
# ~/anaconda3/envs/py39/lib/python3.9/site-packages/theano/utils.py in output_subprocess_Popen(command, **params)
#     252     # we need to use communicate to make sure we don't deadlock around
#     253     # the stdout/stderr pipe.
# --> 254     out = p.communicate()
#     255     return out + (p.returncode,)
#     256
#
# ~/anaconda3/envs/py39/lib/python3.9/subprocess.py in communicate(self, input, timeout)
#    1132
#    1133             try:
# -> 1134                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1135             except KeyboardInterrupt:
#    1136                 # https://bugs.python.org/issue25942
#
# ~/anaconda3/envs/py39/lib/python3.9/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1977                             'failed to raise TimeoutExpired.')
#    1978
# -> 1979                     ready = selector.select(timeout)
#    1980                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1981
#
# ~/anaconda3/envs/py39/lib/python3.9/selectors.py in select(self, timeout)
#     414         ready = []
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#     418             return ready
#
# KeyboardInterrupt:

# %%
sim_folder = './simulated_data/Dec14/'


sim_files = [
    'period4327_inc45_gaia60_roman5_5_100gaia.csv',
    'period4327_inc45_gaia60_roman5_5_200gaia.csv',
    'period4327_inc45_gaia60_roman5_10_100gaia.csv',
    'period4327_inc45_gaia60_roman5_10_200gaia.csv',
    
    'period4327_inc45_gaia60_roman10_5_100gaia.csv',
    'period4327_inc45_gaia60_roman10_5_200gaia.csv',
    'period4327_inc45_gaia60_roman10_10_100gaia.csv',
    'period4327_inc45_gaia60_roman10_10_200gaia.csv',
    
    'period4327_inc45_gaia60_roman20_5_100gaia.csv',
    'period4327_inc45_gaia60_roman20_5_200gaia.csv',
    'period4327_inc45_gaia60_roman20_10_100gaia.csv',
    'period4327_inc45_gaia60_roman20_10_200gaia.csv',
    
    'period4327_inc45_gaia60_romanNA_100gaia.csv',
    'period4327_inc45_gaia60_romanNA_200gaia.csv'
]


simulated_data = []
for file in sim_files:
    df = pd.read_csv(sim_folder + file)
    simulated_data.append(df)
    #print(simulated_data)
    
simulated_data = simulated_data[0]
x_rv = simulated_data['x_rv'].values
y_rv = simulated_data['y_rv'].values
y_rv_err = simulated_data['y_rv_err'].values
x_astrometry = simulated_data['x_astrometry'].values
y_ra = simulated_data['y_ra'].values
y_dec = simulated_data['y_dec'].values
y_ra_err = simulated_data['y_ra_err'].values
y_dec_err = simulated_data['y_dec_err'].values


plt.plot(x_rv, y_rv)

# %%
def make_plots(roman_vars, simulated_data, trace_file, trace_folder):
    
    x_rv = simulated_data['x_rv'].values
    y_rv = simulated_data['y_rv'].values
    y_rv_err = simulated_data['y_rv_err'].values
    x_astrometry = simulated_data['x_astrometry'].values
    y_ra = simulated_data['y_ra'].values
    x_astrometry = simulated_data['x_astrometry'].values
    y_dec = simulated_data['y_dec'].values
    y_ra_err = simulated_data['y_ra_err'].values
    y_dec_err = simulated_data['y_dec_err'].values
          
              
    
    
    # add NaN for plotting purpose on true model
    times_astrometry = np.insert(times_astrometry, 10000, float('NaN'))
    ra_orbit = np.insert(ra_orbit, 10000, float('NaN'), axis=0)
    dec_orbit = np.insert(dec_orbit, 10000, float('NaN'),axis=0)
            
    
    tot_dec_err = roman_vars
    


    with open(folder+file, 'rb') as buff:
        data = pickle.load(buff)  

    model, trace = data['model'], data['trace']
    
    
    
    
    ################
    #plot astrometry
    
    figAs, ax = plt.subplots(2, 2, figsize = [18,9], sharey=True)
    for n, letter in enumerate(["Earth", "Jupiter"]):
        ax0, ax1 = ax[n][0], ax[n][1]

        # Get the posterior median orbital parameters
        p = np.median(trace.posterior["P"].values[:, :, n])
        t0 = np.median(trace.posterior["tperi"].values[:, :, n])

        # Compute the median of posterior estimate the other planet. Then we can remove
        # this from the data to plot just the planet we care about.
        other = np.median(
            trace.posterior["dec"].values[:, :, :, (n + 1) % 2], axis=(0, 1)
        )






        # plot the DEC data
        ax0.errorbar(x_astrometry, dec_data - other, yerr=dec_err, fmt=".", 
                     color = "#00257c", label = "data", alpha = 0.7)

        # plot the MCMC DEC model
        pred = np.percentile(
            trace.posterior["dec_fine"].values[:, :, :, n],
            [16, 50, 84],
            axis=(0, 1),
        )


        ax0.plot(t_fine, pred[1], color="k", label="MCMC model")
        art = ax0.fill_between(
            t_fine, pred[0], pred[2], color="k", alpha=0.3
        )
        art.set_edgecolor("none")


        # plot the true DEC model
        ax0.plot(times_astrometry, dec_orbit.T[n], color = 'r', label = "true model")








        # Get the posterior median orbital parameters
        p = np.median(trace.posterior["P"].values[:, :, n])
        t0 = np.median(trace.posterior["tperi"].values[:, :, n])

        # Compute the median of posterior estimate the other planet. Then we can remove
        # this from the data to plot just the planet we care about.
        other = np.median(
            trace.posterior["ra"].values[:, :, :, (n + 1) % 2], axis=(0, 1)
        )
        





        # Plot the RA data
        ax1.errorbar(x_astrometry, ra_data - other, yerr=ra_err, fmt=".", 
                     color = "#00257c", label = "data", alpha = 0.7)


        pred = np.percentile(
            trace.posterior["ra_fine"].values[:, :, :, n],
            [16, 50, 84],
            axis=(0, 1), 
        )



        # plot the MCMC RA model
        ax1.plot(t_fine, pred[1], color="k", label="MCMC model")
        art = ax1.fill_between(
            t_fine, pred[0], pred[2], color="k", alpha=0.3
        )
        art.set_edgecolor("none")
        
        # plot the true RA model
        ax1.plot(times_astrometry, ra_orbit.T[n], color = 'r', label = "true model")








        ax0.legend(fontsize=18, loc=3)
        ax0.set_xlabel("time [days]", fontsize=18)
        ax0.set_ylabel(r"$\Delta \delta$ ['']", fontsize = 18)
        ax0.set_title("{0} Dec".format(letter), fontsize=27)
        
        ax1.legend(fontsize=18, loc=3)
        ax1.set_xlabel("time [days]", fontsize=18)
        ax1.set_ylabel(r"$\Delta \alpha \cos \delta$ ['']", fontsize = 18)
        ax1.set_title("{0} RA".format(letter), fontsize=27)

        
        
        
        
        #ax[1].set_ylabel(r"[O-C]", fontsize = 36)
        #ax[3].set_ylabel(r"[O-C]", fontsize = 36)
        figAs.tight_layout()
        figAs.suptitle('Astrometry: ' + file[:-4], fontsize=36)
        #fig.savefig('./comparison_figures2/astrometry_'+file+'.pdf')
        
        
        
        
        
            
        
        
    ######
    #make rv plots
    matplotlib.rc('xtick', labelsize=18) 
    matplotlib.rc('ytick', labelsize=18)
    change_to_NaN = False #creates gap in plot
    figRV, axs = plt.subplots(2, 1, figsize = [13, 9])
    for n, letter in enumerate(["Earth", "Jupiter"]):
        ax = axs[n]

        # Get the posterior median orbital parameters
        p = np.median(trace.posterior["P"].values[:, :, n])
        t0 = np.median(trace.posterior["tperi"].values[:, :, n])

        # Compute the median of posterior estimate the other planet. Then we can remove
        # this from the data to plot just the planet we care about.
        other = np.median(
            trace.posterior["vrad"].values[:, :, :, (n + 1) % 2], axis=(0, 1)
        )







        # Plot the data
        ax.errorbar(x_rv, y_rv - other, yerr=y_rv_err, fmt=".", 
                     color = "#00257c", label = "data", alpha = 0.7)


        pred = np.percentile(
            trace.posterior["vrad_pred"].values[:, :, :, n],
            [16, 50, 84],
            axis=(0, 1),
        )

        #t_plot = t_fold[inds].copy()
        #for ii in range(1, len(t_plot)):
        #    if t_plot[ii] - t_plot[ii-1] > 180:
        #        change_to_NaN = True
        #        NaN_index = ii

        #if change_to_NaN:
        #    t_plot[NaN_index] = float('NaN')
        #    t_plot[NaN_index-1] = float('NaN')
        #    change_to_NaN = False

        
        # plot the MCMC model
        ax.plot(t_rv, pred[1], color="k", label="MCMC model")
        art = ax.fill_between(
            t_rv, pred[0], pred[2], color="k", alpha=0.3
        )
        art.set_edgecolor("none")
        
        # plot the true RA model
        ax.plot(times_rv, rv_orbit.T[n], color = 'r', label = "true model")








        ax.legend(fontsize=18, loc=1)
        ax.set_xlabel("phase [days]", fontsize=18)
        ax.set_ylabel("radial velocity [m/s]", fontsize=18)
        ax.set_title("{0}".format(letter), fontsize=27)


        figRV.tight_layout()
        figRV.subplots_adjust(hspace=0.5)
        #fig.savefig('./comparison_figures2/rv_'+ file+'.pdf')
        figRV.suptitle('RV: ' + file[:-4], fontsize=36)
        
        
    return figAs, figRV

# %%
folder = './traces/Dec14/'


files = [
    'period4327_inc45_gaia60_roman5_5_100gaia.cdf',
    'period4327_inc45_gaia60_roman5_5_200gaia.cdf',
    'period4327_inc45_gaia60_roman5_10_100gaia.cdf',
    'period4327_inc45_gaia60_roman5_10_200gaia.cdf',
    
    'period4327_inc45_gaia60_roman10_5_100gaia.cdf',
    'period4327_inc45_gaia60_roman10_5_200gaia.cdf',
    'period4327_inc45_gaia60_roman10_10_100gaia.cdf',
    'period4327_inc45_gaia60_roman10_10_200gaia.cdf',
    
    'period4327_inc45_gaia60_roman20_5_100gaia.cdf',
    'period4327_inc45_gaia60_roman20_5_200gaia.cdf',
    'period4327_inc45_gaia60_roman20_10_100gaia.cdf',
    'period4327_inc45_gaia60_roman20_10_200gaia.cdf',
    
    'period4327_inc45_gaia60_romanNA_100gaia.cdf',
    'period4327_inc45_gaia60_romanNA_200gaia.cdf',
]

period_jup = 4327
inc_earth = 45.0
roman_vars =[
    [5e-6,5],
    [5e-6,5],
    [5e-6,10],
    [5e-6,10],
    [10e-6,5],
    [10e-6,5],
    [10e-6,10],
    [10e-6,10],
    [20e-6,5],
    [20e-6,5],
    [20e-6,10],
    [20e-6,10],
    [None,None]
]
gaia_obs = [100, 200]


P_earth = 300
e_earth = 0.0167
Tper_earth= 100
omega_earth = np.radians(102.9)
Omega_earth = np.radians(0.0)
inclination_earth = np.radians(inc_earth)
m_earth = 1*3.00273e-6 #units m_sun



P_jup = period_jup
e_jup = 0.0484
Tper_jup = 500
omega_jup = np.radians(274.3) - 2*np.pi
Omega_jup = np.radians(100.4)
inclination_jup = np.radians(1.31) + inclination_earth
m_jup = 317.83*3.00273e-6 #units m_sun


from matplotlib.backends.backend_pdf import PdfPages

for ii in range(0, len(roman_vars)):
    figs = make_plots(roman_vars[ii], files[ii], folder)
    #pp = PdfPages('comparison_figures2/diagnostic'+str(ii+1)+'.pdf')
    #pp.savefig(figs[1])
    #pp.savefig(figs[0])
    #pp.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c7d31fe4caaa> in <module>
#      64
#      65 for ii in range(0, len(roman_vars)):
# ---> 66     figs = make_plots(roman_vars[ii], files[ii], folder)
#      67     #pp = PdfPages('comparison_figures2/diagnostic'+str(ii+1)+'.pdf')
#      68     #pp.savefig(figs[1])
#
# <ipython-input-10-67ec9c255177> in make_plots(roman_vars, file, folder)
#       2 #for ii in range(0, len(roman_vars)):
#       3     x_rv, t_rv, y_rv, y_rv_err, x_astrometry, t_astrometry, t_fine,\
# ----> 4     ra_data, dec_data, ra_err, dec_err, times_rv, times_astrometry, rv_orbit, ra_orbit, dec_orbit = sim_data(
#       5         inc_earth, period_jup, roman_vars[0], roman_vars[1], gaia_obs)
#       6
#
# NameError: name 'sim_data' is not defined
