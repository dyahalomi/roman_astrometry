# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('xtick', labelsize=27) 
matplotlib.rc('ytick', labelsize=27)

# %%
data = pd.read_csv('exoplanet_data_sun-like.csv')
data_all = pd.read_csv('exoplanet_data.csv')

# %%
print(data.columns)
# Out:
# Index(['pl_name', 'soltype', 'pl_controv_flag', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_masse', 'pl_masseerr1',
#        'pl_masseerr2', 'pl_masselim', 'st_rad', 'st_raderr1', 'st_raderr2',
#        'st_radlim', 'st_mass', 'st_masserr1', 'st_masserr2', 'st_masslim',
#        'st_age', 'st_ageerr1', 'st_ageerr2', 'st_agelim'],
#       dtype='object')

# %%
periods = data['pl_orbper']
masses = data['pl_masse']


periods_all = data_all['pl_orbper']
masses_all = data_all['pl_masse']

# %%
m_earth = 1.
p_earth = 365.25

# %%
m_jup = 317.83
p_jup = 4327.631

# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

def getImage(path):
    return OffsetImage(plt.imread(path))

# %%
fig, ax = plt.subplots(1, 1, figsize = [15,15])
ax.plot(periods, masses, 'o', color = "#7b3e65", alpha = 0.3, markersize = 13)


ax.set_yscale('log')
ax.set_xscale('log')




paths = [
    'earth.png',
    'jupiter.png',
    ]

y = [m_earth,m_jup]
x = [p_earth,p_jup]

ax.scatter(x, y) 

for x0, y0, path in zip(x, y, paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), 
                        frameon=False)
    ax.add_artist(ab)
    

ax.set_xlim(.1, 100000)
ax.set_ylim(.1, 10000)

ax.set_ylabel(r'mass [M$_{Earth}$]', fontsize = 36)
ax.set_xlabel('orbital period [days]', fontsize = 36)

ax.set_title('confirmed exoplanets around Sun-like stars', fontsize = 36)
fig.savefig('final_figures/exoplanets_sun-like.pdf')

fig.tight_layout()

# %%
fig, ax = plt.subplots(1, 1, figsize = [15,15])
ax.plot(periods_all, masses_all, 'o', color = "#7b3e65", alpha = 0.3, markersize = 13)


ax.set_yscale('log')
ax.set_xscale('log')




paths = [
    'earth.png',
    'jupiter.png',
    ]

y = [m_earth,m_jup]
x = [p_earth,p_jup]

ax.scatter(x, y) 

for x0, y0, path in zip(x, y, paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), 
                        frameon=False)
    ax.add_artist(ab)
    

ax.set_xlim(.1, 100000)
ax.set_ylim(.1, 10000)

ax.set_ylabel(r'mass [M$_{Earth}$]', fontsize = 36)
ax.set_xlabel('orbital period [days]', fontsize = 36)

ax.set_title('confirmed exoplanets', fontsize = 36)

fig.savefig('final_figures/exoplanets_all.pdf')
