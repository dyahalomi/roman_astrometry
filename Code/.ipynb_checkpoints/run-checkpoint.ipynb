# %%
from simulate_and_model import *
# Out:
# WARNING (theano.link.c.cmodule): install mkl with `conda install mkl-service`: No module named 'mkl'
# exoplanet.__version__ = '0.5.1'

# %%
incs = [10., 45., 80.]
#errs = [5e-6, 10e-6, 20e-6]
errs = [None]


for inc in incs:
    for roman_err in errs:
        #print('start... inc: ' + str(int(inc)) + ', roman_err: ' + str(int(1e6*roman_err)))
        print('start... inc: ' + str(int(inc)) + ', roman_err: 
        simulate_and_model_data(inc, roman_err)
# Out:
# start... inc: 10, roman_err: 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-cc3002ee6594> in <module>
#       6     for roman_err in errs:
#       7         print('start... inc: ' + str(int(inc)) + ', roman_err: ' + str(int(1e6*roman_err)))
# ----> 8         simulate_and_model_data(inc, roman_err)
#
# ~/Documents/Columbia/Research/RomanAstrometry/Code/simulate_and_model.py in simulate_and_model_data(inc, roman_err)
#     114
#     115
# --> 116 	times, rv_results, ra_results, dec_results = simulate_data(
#     117                 n_planets,
#     118                 sigma_rv,
#
# ~/Documents/Columbia/Research/RomanAstrometry/Code/simulate.py in simulate_data(n_planets, sigma_rv, sigma_ra, sigma_dec, plx, orbit_params, times_observed_rv, times_observed_astrometry, t_dur_rv, n_obs_rv, t_dur_astrometry, n_obs_astrometry)
# ...
